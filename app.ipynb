# %%
import pandas as pd 
import numpy as np

# %%
from sklearn.model_selection import train_test_split 
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.linear_model import LogisticRegression 
import re 
import joblib
import string

# %%
fake = pd.read_csv('fake.csv')

# %%
true = pd.read_csv('true.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true.columns
fake.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
# set the class label in dataset 
fake['class']=0
true['class']=1

# %%
# combine both the dataset

data = pd.concat([fake,true],axis = 0)

# %%
data.sample(30)
# Out:
#                                                    title  \
# 16364  MISSING: TWO FILE ‘BOXES’ OF CLINTON E-MAILS…E...
# 5946   Two Florida ports cancel plans to ink pacts wi...
# 3418   Trump travel ban's fate hinges on emergency U....
# 7240   Trump denies trying to get security clearance ...
# 13050  South Korean President Moon to visit China Dec...
# 19922  Trump to meet with long list of leaders in New...
# 9068   JUST IN: PRESIDENT TRUMP AND FIRST LADY Make S...
# 17056  Iraq orders arrest of Kurdistan vice president...
# 5       Racist Alabama Cops Brutalize Black Boy While...
# 10262  Romney offers vote, little else, to Cruz in Re...
# 13599  BENGHAZI WIDOW Hits Back At Hillary’s Heartles...
# 15990  FOX LEGAL EXPERT CALLS OUT ‘PARTIAL’ MUELLER: ...
# 7344   Trump strongly considering naming campaign chi...
# 9138   CHRIS CHRISTIE Gets Frustrated…SNAPS At MSNBC ...
# 9817   Donald Trump's unlikely villain: piano-playing...
# 22236  Potential Shift: Trump Warns Israel, ‘New Sett...
# 4686    Trump Just Took To Twitter To Proudly Defend ...
# 16553  Three killed, one missing after torrential rai...
# 20167  CNN IS EVIL: Carol Costello FAILS When Benghaz...
# 16890  IS OBAMA’S RADICAL AGENDA Responsible For Stat...
# 23161  Episode #160 – SUNDAY WIRE: ‘Hail to the Deplo...
# 15853  NOT NEWS: [Graphic Video] Michigan Woman Runs ...
# 14439  HOLY WIDOWS AND ORPHANS! Over 5,000 ISIS Train...
# 6695   Trump could find Democratic allies on tax refo...
# 16190  WHICH ONE OF THESE PEOPLE Tried to Lecture the...
# 55      Sean Hannity Is Throwing A Stage-4 Temper Tan...
# 23435  Blood Sport: GOP Presidential Race Takes Anoth...
# 10007  What? First Graders Asked Not to Use the Words...
# 11919  Croatia and Slovenia fail to move forward in t...
# 20473  After insurgents' truce, Myanmar says 'we don'...
#
#                                                     text          subject  \
# 16364  FBI files reveal missing email  boxes  in Clin...  Government News
# 5946   MIAMI (Reuters) - Two Florida ports have cance...     politicsNews
# 3418   WASHINGTON (Reuters) - President Donald Trump ...     politicsNews
# 7240   WASHINGTON (Reuters) - Republican President-el...     politicsNews
# 13050  BEIJING (Reuters) - South Korean President Moo...        worldnews
# 19922  WASHINGTON (Reuters) - U.S. President Donald T...        worldnews
# 9068    President Trump visits Florida hospital, prai...         politics
# 17056  BAGHDAD (Reuters) - Iraq s Supreme Justice Cou...        worldnews
# 5      The number of cases of cops brutalizing and ki...             News
# 10262  WASHINGTON (Reuters) - Republican Mitt Romney ...     politicsNews
# 13599  Dorothy Woods, the wife of an ex-Navy SEAL kil...         politics
# 15990  Gregg Jarrett says Mueller must resign after h...  Government News
# 7344   WASHINGTON (Reuters) - President-elect Donald ...     politicsNews
# 9138   New Jersey Republican Governor Chris Christie ...         politics
# 9817   HOLLYWOOD, Fla. (Reuters) - Reince Priebus, th...     politicsNews
# 22236  21st Century Wire says Incredibly, Donald Trum...          US_News
# 4686   Most of the media is capitalizing off what Hil...             News
# 16553  SOFIA (Reuters) - Three people were killed and...        worldnews
# 20167  Charles Woods, father of U.S. Navy SEAL Tyrone...        left-news
# 16890  President Barack Obama has called the fight ag...  Government News
# 23161   Episode #160 of SUNDAY WIRE SHOW resumes this...      Middle-east
# 15853  This is a story that will never make the news....         politics
# 14439  Europe s new new take on our Statue of Liberty...         politics
# 6695   WASHINGTON (Reuters) - In the looming tax refo...     politicsNews
# 16190                                                     Government News
# 55     We re not sure why Fox News host Sean Hannity ...             News
# 23435  Patrick Henningsen 21st Century WireAs Baron R...      Middle-east
# 10007  What the heck happened to our freedom of speec...         politics
# 11919  ZAGREB (Reuters) - Croatia and Slovenia failed...        worldnews
# 20473  YANGON/SHAH PORIR DWIP ISLAND, Bangladesh (Reu...        worldnews
#
#                       date  class
# 16364          Oct 6, 2016      0
# 5946     January 27, 2017       1
# 3418         June 2, 2017       1
# 7240    November 16, 2016       1
# 13050    December 6, 2017       1
# 19922  September 15, 2017       1
# 9068             16-Feb-18      0
# 17056    October 19, 2017       1
# 5        December 25, 2017      0
# 10262      March 18, 2016       1
# 13599         Jun 30, 2016      0
# 15990          Aug 3, 2017      0
# 7344    November 10, 2016       1
# 9138          Dec 21, 2017      0
# 9817       April 24, 2016       1
# 22236     February 2, 2017      0
# 4686    September 11, 2016      0
# 16553    October 25, 2017       1
# 20167          Aug 5, 2016      0
# 16890         Dec 26, 2015      0
# 23161    November 13, 2016      0
# 15853          Apr 9, 2015      0
# 14439         Feb 21, 2016      0
# 6695    December 15, 2016       1
# 16190         Mar 21, 2017      0
# 55       November 28, 2017      0
# 23435    February 26, 2016      0
# 10007         Aug 31, 2017      0
# 11919   December 19, 2017       1
# 20473  September 10, 2017       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44898 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   class    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ MB

# %%
# drop the features which are not required

data = data.drop(["title","subject","date"],axis = 1)

# %%
data.reset_index(inplace =True)

# %%
data.drop(['index'],axis =1,inplace=True)

# %%
data.head()
# Out:
#                                                 text  class
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
data.sample(5)
# Out:
#                                                     text  class
# 37505  PARIS (Reuters) - French President Emmanuel Ma...      1
# 23187  Patrick Henningsen 21st Century Wire Hillary C...      0
# 1151   Attorney General Jeff Sessions appeared before...      0
# 41714  (Reuters) - A Spanish Constitutional Court rul...      1
# 20808  Obama s cowardly backdoor gun confiscation sta...      0

# %%
# data cleaning

def clean_text(text):
    # convert into lowercase   
    text = text.lower()                                                                                    
    text = re.sub(r'\[.*?\]', "", text)                                                          
    text = re.sub(r'\W', " ", text)
     # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', "", text)
    # Remove HTML tags
    text = re.sub(r'<.*?>+', "", text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), "", text)
    # Remove New line
    text = re.sub(r'\n', " ", text)
    text = re.sub(r'\w*\d\w*', "", text)
    return text

# %%
# apply this function to the text column in dataset

data["text"] = data["text"].apply(clean_text)

# %%
# create a X and Y variable for model
x = data["text"]
y = data["class"]

# %%
# train test split

xtrain ,xtest, ytrain, ytest = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
xtrain.shape
ytest.shape
# Out:
# (11225,)

# %%
# use tfidfvectorizer for converting the categorical data into numerical data

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test = vectorizer.transform(xtest)

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2285159 stored elements and shape (11225, 94931)>

# %%
# logistic regression

lr = LogisticRegression()
lr.fit(xv_train,ytrain)
# Out:
# LogisticRegression()

# %%
# prediction

prediction = lr.predict(xv_test)
lr.score(xv_test,ytest)
# Out:
# 0.9858351893095768

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
from sklearn.tree import  DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()
DTC.fit(xv_train,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test,ytest)
# Out:
# 0.9956347438752784

# %%
print(classification_report(ytest,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5895
#            1       1.00      1.00      1.00      5330
#
#     accuracy                           1.00     11225
#    macro avg       1.00      1.00      1.00     11225
# weighted avg       1.00      1.00      1.00     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']

# %%
joblib.dump(DTC,"DTC_model.jb")
# Out:
# ['DTC_model.jb']
